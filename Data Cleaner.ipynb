# %%
import pandas as pd
import numpy as np

import os

# %%
Formspring = os.path.join('final_data', 'Formspring.csv')
Formspring = pd.read_csv(Formspring)
Bayzick = os.path.join('final_data', 'bayzick_label.csv')
Bayzick = pd.read_csv(Bayzick)
Bayzick['Text'] = Bayzick['Text'].str.replace('â\xa0', '').str.replace('ã\x82', '').str.replace('ã¢â\x82', '').str.replace('ã¢', '').str.replace('ã¦', '').str.replace('â\x80', '').str.replace('¬å\x93', '').str.replace('¬â\x84¢', '').str.replace('\x94', '').str.replace('¢', '').str.replace('â', '')
Bayzick.to_csv()
# Out:
#       Label                                               Text
# 0         0  i just have to say that is the coolest freakin...
# 1         0  i saw it when i was like 15. i think back and ...
# 2         0  great film.one of the best films i ever viddie...
# 3         0  one of the best films i ever viddied.great fuc...
# 4         0  great fucking movie!! one of the best ever.gre...
# 5         0  great movie. very unique!friggin awesome flick...
# 6         0  it's an incredible film. stanley kubrick is su...
# 7         0  stanley kubrick, and seeing "clockwork orange"...
# 8         0  another fan here.    i even dressed like alex ...
# 9         0  great film, book and soundtrack. one of kubric...
# 10        0  that a brillent movie  and the look of it  it ...
# 11        0  kubrick is probably the most overated director...
# 12        0  a clockwork orange is my second-favorite film....
# 13        0  excellent movie, excellent book. people think ...
# ...
