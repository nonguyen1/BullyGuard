# %%
import pandas as pd
import numpy as np

import os

# %%
Formspring = os.path.join('final_data', 'Formspring.csv')
flights = pd.read_csv(Formspring)
flights
# Out:
#                                                     TEXT    ANSWER
# 0      !  I'm a close frien wel thankyouuu  and i tru...  0.000000
# 1        ! W@N+ YUh 2 T3@R M@ PU$$$Y UHP dnt worry iWill  0.000000
# 2      ! W@NTt Y3Ww TA SW@Ll0wW M@ T@MP0N DH3N PUT !T...  0.333333
# 3      ! w@N+ yUh +0 $M@(K m3 & m@k3 dH@ SEx w!Ld n h...  0.000000
# 4          ! w@n+ y0 b!q d!(k $uRf@(!n m@ l!pSz$ anytyme  0.333333
# 5                ! w@n+ yUh t@ m@k3 m3 $w3@+ ohkay iWill  0.000000
# 6      ! w@nN@ l!qqhH+ y0 d!(K 0N f!r3 N d3nN sM0k3 !...  0.333333
# 7      ! w@nn@ fuck y0u. @nd y0u d!d f0rq3+ @b0u+ d@+...  0.000000
# 8                   ! wUnN@ sU(k y0 d!(k so kum nd do it  0.333333
# 9      !M h00000rNyY f0 y@ d!(k n!qq@ ! w@n+ y3w t@ q...  0.000000
# 10     !f ! @cC3pT wut yuH qon3 duuuu f@ mii tell mi ...  0.000000
# 11     !m @ q!rl d03 ! $0 ju$+ cum @n l!(k m@ cum n m...  0.333333
# 12     !m@ b3 pu++!n d!$ pu$$zzy 0n y@ $!d3 burn$ !n ...  0.666667
# ...
